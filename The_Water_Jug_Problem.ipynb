# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditi-Chowdhury2005/AI-ML-Project/blob/main/The_Water_Jug_Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install network matplotlib
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for network: filename=network-0.1-py3-none-any.whl size=3138 sha256=9a552bcaf3be6e31c91c75c222c709ae3999df18616434488f754460d0eb7461
#   Stored in directory: /root/.cache/pip/wheels/93/07/5a/a207d6b2ad046d88823c537dd409331218b5f55aa206e820ac
# Successfully built network
# ...

# %%
#problem2
from collections import deque

def water_jug_bfs():
    capacity = (4, 3)
    start = (0, 0)
    queue = deque([(start, [])])
    visited = {start}

    while queue:
        (a, b), path = queue.popleft()

        if a == 2 or b == 2:
            return path + [(a, b)]

        states = [
            (4, b),                         # Fill A
            (a, 3),                         # Fill B
            (0, b),                         # Empty A
            (a, 0),                         # Empty B
            (a - min(a, 3-b), b + min(a, 3-b)),  # A -> B
            (a + min(b, 4-a), b - min(b, 4-a))   # B -> A
        ]

        for state in states:
            if state not in visited:
                visited.add(state)
                queue.append((state, path + [(a, b)]))

    return None


solution = water_jug_bfs()

print("Minimum Steps:")
for i, state in enumerate(solution):
    print(f"Step {i}: Jug A = {state[0]}L, Jug B = {state[1]}L")
# Out:
# Minimum Steps:
# Step 0: Jug A = 0L, Jug B = 0L
# Step 1: Jug A = 0L, Jug B = 3L
# Step 2: Jug A = 3L, Jug B = 0L
# Step 3: Jug A = 3L, Jug B = 3L
# Step 4: Jug A = 4L, Jug B = 2L
